# %% [raw]
# ---
# title: "Project Proposal"
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     code-fold: show
#     embed-resources: true
# jupyter: python3
# ---

# %% [markdown]
# ### 1) Name

# %% [markdown]
# Ryan Shen

# %% [markdown]
# ### 2) Project Topic/Title

# %% [markdown]
# Chicago Crash Correlations with Climate Conditions

# %% [markdown]
# ### 3) Inspiration
#
# Explain the reason for your choice of data. Why is it interesting to you? Why do you think it is worth exploring for this project? Include any motivations or background that you believe is relevant. **(0.5 points)**

# %% [markdown]
# Having personally witnessed a large car crash last summer, I became quite personally invested in trying to understand the circumstances surrounding car crashes in Chicago, such as the speed of the vehicles involved, the general location, and the weather conditions surrounding the crash. Car crashes are also the leading cause of death for young people below the age of 22 and the 2nd most common cause of death for people from ages 22 to 67. Analysis of this data could provide guidelines that lower car crashes, which I would greatly desire.

# %% [markdown]
# ### 4)  Data
#
# - Identify and and describe your data source(s). **Share any related links and/or citations**.
# - **Using some code**, demonstrate that you have been able to read the data. Along with this, give a brief overview of the data:
#     - How many observations?
#     - How many variables? How many of them are numeric and how many of them are categorical? (Remember that not all non-numeric variables are categorical!)
#     - Is there any missing values? Will cleaning/imputing be necessary?
#
# **(2 points)**

# %% [markdown]
# Source 1: https://data.cityofchicago.org/Transportation/Traffic-Crashes-Crashes/85ca-t3if/about_data
#
# Source 2: https://www.wunderground.com/history/daily/us/il/chicago/KMDW (datascraped by me; script using for scraping available on request)
#
# (I asked Prof. Besler if I could combine some of the weather data as I scraped into the crash data as a supplementary factor and he approved of my plan.)
#
# There are approximately 1.008 million observations in the crash data.
#
# 18 of the variables are numeric (I'm including date counts as numeric as I plan to ask questions about crashes over time), and the remaining 30 variables are categorical.
#
# Some data like injuries and the location/latitude/longitude have missing values from the dataset; those rows will have to be cleaned out, as imputation is not possible.
#
# There are 233,414 observations in the weather data.
# 9 of the variables are numeric and 2 are categorical. This is less than 10 numeric variables, but since this is supplementary data that is meant to be added onto the crash data set, combined with the crash data variables it will be more than 10 in total.
#
# There are some missing hours from the dataset, which means I will have to impute values from adjacent days at a similar time.

# %%
import pandas as pd
weather = pd.read_csv('KMDW.csv')
weather.describe(include='all')
# Out:
#               Date      Time  Temperature_C    Dew_Point_C     Humidity_%  \
# count       233414    233414  233414.000000  233414.000000  233414.000000
# unique        8978      1369            NaN            NaN            NaN
# top     2017-10-14  11:53 PM            NaN            NaN            NaN
# freq            48      5861            NaN            NaN            NaN
# mean           NaN       NaN      11.223014       4.440814      66.773831
# std            NaN       NaN      11.268999      10.704576      17.323740
# min            NaN       NaN     -29.440000     -35.560000       0.000000
# 25%            NaN       NaN       2.220000      -3.330000      54.000000
# 50%            NaN       NaN      11.670000       5.000000      68.000000
# 75%            NaN       NaN      21.110000      13.330000      80.000000
# max            NaN       NaN      40.000000      26.110000     100.000000
#
#        Wind Direction  Speed in km/h      Gust km/h  Pressure in hPa  \
# ...

# %%
weather.head()
# Out:
#          Date      Time  Temperature_C  Dew_Point_C  Humidity_%  \
# 0  2000-01-24  12:53 AM         -15.00       -20.00        66.0
# 1  2000-01-24  01:53 AM         -15.56       -20.00        70.0
# 2  2000-01-24  02:53 AM         -16.11       -20.00        73.0
# 3  2000-01-24  03:53 AM         -16.67       -20.00        76.0
# 4  2000-01-24  04:53 AM         -16.67       -20.56        72.0
#
#   Wind Direction  Speed in km/h  Gust km/h  Pressure in hPa  \
# 0            WNW          14.48        0.0          1001.69
# 1            WNW          11.26        0.0          1001.69
# 2            WNW           9.65        0.0          1002.03
# 3            WNW          14.48        0.0          1002.37
# 4            WNW          11.26        0.0          1002.71
#
#    Precipitation Rate in mm Condition
# 0                       0.0      Fair
# 1                       0.0      Fair
# 2                       0.0      Fair
# 3                       0.0      Fair
# ...

# %%
crash = pd.read_csv('Traffic_Crashes_-_Crashes_20251109.csv')
crash.describe(include='all')
# Out:
# /var/folders/_l/b38cj6s513957kzfnj_20g5m0000gn/T/ipykernel_26355/1088546506.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   crash = pd.read_csv('Traffic_Crashes_-_Crashes_20251109.csv')
#                                           CRASH_RECORD_ID CRASH_DATE_EST_I  \
# count                                             1000814            72697
# unique                                            1000814                2
# top     997792115d42cf0a06981dc63acab07dbb65ec3cc1afcf...                Y
# freq                                                    1            63404
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# ...

# %%
crash.head()
# Out:
#                                      CRASH_RECORD_ID CRASH_DATE_EST_I  \
# 0  997792115d42cf0a06981dc63acab07dbb65ec3cc1afcf...              NaN
# 1  a96af10f9272c97183da517905da458dcf0025b9925867...              NaN
# 2  31563af4e4fa96c77061cf4e3723716a0961eb6266bf1b...              NaN
# 3  003883bd9375824b71be65e30bb7519280873e7bf378f5...              NaN
# 4  0cbecb09d445225d0995a98c4dc668001c18a538dc6e54...              NaN
#
#                CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 0  11/09/2025 03:28:00 AM                  30         TRAFFIC SIGNAL
# 1  11/09/2025 02:53:00 AM                  30            NO CONTROLS
# 2  11/09/2025 02:04:00 AM                  25         TRAFFIC SIGNAL
# 3  11/09/2025 02:00:00 AM                  25         TRAFFIC SIGNAL
# 4  11/09/2025 01:55:00 AM                  20            NO CONTROLS
#
#        DEVICE_CONDITION WEATHER_CONDITION      LIGHTING_CONDITION  \
# ...

# %% [markdown]
# ### 5) Questions
#
# - What are the questions to be answered in the report? **You should have at least two and at most four questions.**
# - For each question, briefly mention your plan to analyze the data and to answer the question.
#
# **(2 points)**

# %% [markdown]
# 1. Are there any locations in Chicago where crash occurrences congregate, and have these areas changed over time? I plan to plot out the latitude and longitude of each crash on a heatmap and observe which areas in the city have experienced the most crashes, during specific time periods.
#
# 2. How do weather conditions and posted speed limits correlate to deadlier injuries in a crash or higher numbers of traffic accidents? I plan to use pairwise correlation to track the relationship between variables such as posted speed limits, precipitation levels, wind speeds and temperature with variables such as the rate of injuries and the amount of crashes during certain conditions (for example, the number of crashes for each level of precipitation). I plan to visualize this data with pairplots and histograms for each relevant relationship.
#
# 3. Have crashes in Chicago became more frequent/deadlier, and which seasons within Chicago experiences the most crashes and the deadliest crashes? I plan to group crashes in Chicago by the time they occur and observe the crash counts and the injury rates of each timespan, and visualize this data using a line graph.

# %% [markdown]
# ### 6) Stakeholders

# %% [markdown]
# Who would be the stakeholders of this project, i.e. who would be interested in hearing your results and how would the result benefit them? **(0.5 points)**

# %% [markdown]
# The stakeholders of this project would include anyone who drives a motor vehicle daily in Chicago; even perfect drivers might become involved in collision due to the actions of another driver or become delayed in traffic as a result of a crash. as well as the city officials of Chicago who have to decide where to post traffic police, speed cameras, and speed limit signs, as well as determine what those speed limits should be. Additionally this data can help tourists decide when the safest times to visit Chicago are.
